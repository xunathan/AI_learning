# %%
import torch

# %% [markdown]
# ## 测试jupyter

# %%
def linear_q_with_scale_and_zero_point(
    tensor,scale,zero_point,dtype=torch.int8):
    scaled_and_shifted_tenfor = tensor / scale + zero_point
    rounded_tensor = torch.round(scaled_and_shifted_tenfor)

    q_min = torch.iinfo(dtype).min
    q_max = torch.iinfo(dtype).max

    q_tensor = rounded_tensor.clamp(q_min, q_max).to(dtype)
    return q_tensor

# %%
test_tensor = torch.tensor(
    [[191.6, -13.5, 728.6],
    [92.14, 295.5, -184],
    [0,684.6, 245.5]])

# %%
scale = 3.5
zero_point = -70

# %%
quantized_tensor = linear_q_with_scale_and_zero_point(test_tensor,scale,zero_point)

# %%
quantized_tensor
# Out:
# tensor([[ -15,  -74,  127],
#         [ -44,   14, -123],
#         [ -70,  126,    0]], dtype=torch.int8)

# %%
dequantized_tensor = scale * (quantized_tensor.float() - zero_point)

# %%
dequantized_tensor
# Out:
# tensor([[ 192.5000,  -14.0000,  689.5000],
#         [  91.0000,  294.0000, -185.5000],
#         [   0.0000,  686.0000,  245.0000]])

# %%
scale * (quantized_tensor - zero_point)
# Out:
# tensor([[ 192.5000,  -14.0000, -206.5000],
#         [  91.0000,  294.0000, -185.5000],
#         [   0.0000, -210.0000,  245.0000]])

# %%
def linear_dequantization(quantized_tensor, scale, zero_point):
    return scale * (quantized_tensor.float() - zero_point)

# %%
from helper import plot_quantization_errors
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 from helper import plot_quantization_errors
#
# ImportError: cannot import name 'plot_quantization_errors' from 'helper' (/opt/homebrew/lib/python3.10/site-packages/helper/__init__.py)

# %%
plot_quantization_errors(test_tensor, quantized_tensor, dequantized_tensor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plot_quantization_errors(test_tensor, quantized_tensor, dequantized_tensor)
#
# NameError: name 'plot_quantization_errors' is not defined
